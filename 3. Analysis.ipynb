# %%
import pandas as pd

# %%
df = pd.read_csv('data/torino_meteo.csv', index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#             Mean Temperature  Min Temperature  Max Temperature  Max Wind  \
# Timestamp
# 1973-01-01               4.3              1.0              6.0      20.2
# 1973-01-02               4.3              2.0              6.0       9.1
# 1973-01-03               5.9              3.0             10.0       7.2
# 1973-01-04               3.7              1.0             10.0       5.4
# 1973-01-05               4.5              1.0              7.0       5.4
#
#             Humidity  Rainfall
# Timestamp
# 1973-01-01      0.95      42.0
# 1973-01-02      0.97      15.0
# 1973-01-03      0.94       6.0
# 1973-01-04      0.92       NaN
# 1973-01-05      0.90       NaN

# %%
df.resample('M')['Max Temperature'].max().plot(figsize=(14, 7))
# Out:
# <Axes: xlabel='Timestamp'>
